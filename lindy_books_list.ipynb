# %%
from src.logic import *

# %%
data = get_ny_times_data('auth.yaml')
# Out:
#                                                title  \
# 0            1,000 RECORDINGS TO HEAR BEFORE YOU DIE
# 1  1,227 QUITE INTERESTING FACTS TO BLOW YOUR SOC...
# 2  1,339 QUITE INTERESTING FACTS TO MAKE YOUR JAW...
# 3                                      10 lb Penalty
# 4                                 10 MINDFUL MINUTES
# 5                               10 POUNDS IN 10 DAYS
# 6                                     10 YEARS LATER
# 7                                        10% HAPPIER
# 8                                           10-10-10
# 9                      10-DAY GREEN SMOOTHIE CLEANSE
#
#                                          description  \
# 0  Operas, rock albums, blues, classical music, w...
# 1  A compilation of interesting information on su...
# 2           Informative morsels of arcana and triva.
# 3                                               None
# 4  Helping children develop emotional tools to co...
# 5
# 6
# ...
