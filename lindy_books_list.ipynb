# %%
from src.logic import *

# %%
data = get_ny_times_data('auth.yaml')
# Out:
#                                      title  \
# 0  1,000 RECORDINGS TO HEAR BEFORE YOU DIE
#
#                                          description  contributor    author  \
# 0  Operas, rock albums, blues, classical music, w...  by Tom Moon  Tom Moon
#
#   contributor_note price age_group publisher  rank list_name display_name  \
# 0                      0             Workman  None      None         None
#
#   published_date bestsellers_date weeks_on_list ranks_last_wek asterix dagger  \
# 0           None             None          None            NaN     NaN   None
#
#   ranks_last_week asterisk
# 0            None     None
#                                                title  \
# 0            1,000 RECORDINGS TO HEAR BEFORE YOU DIE
# 0  1,227 QUITE INTERESTING FACTS TO BLOW YOUR SOC...
#
#                                          description  \
# 0  Operas, rock albums, blues, classical music, w...
# 0  A compilation of interesting information on su...
#
# ...

# %%
data
